# %% [markdown]
# # data types in python
# 1. different vatype of values assigned to variable
# 2. basically 3 data types in python
# 3. int(interger) - numirical values like 1,2,3,4.....n
# 4. str(string) - charecters examples 'ghjk' ,"qwerty"
# 5. float(decimals) - numerical with decimal - 10.25,100,25,125.35....

# %%
name

# %% [markdown]
# # concat

# %%
n1="python"
n2="programming"
print(n1+n2)

# %%
a=100
b="300"
print(a+b)
